# %%
import json

import requests as rq

# %%
url = 'https://lumentum.wd5.myworkdayjobs.com/wday/cxs/lumentum/LITE/jobs'
payload={"appliedFacets":
             {"locations":
                  ["1fb4c923bb630100a0fa8c8bd49a0000","01232ead616f01726660254a6810e472"]},
         "limit":20,
         "offset":40,
         "searchText":""}

# %%
dat=rq.post(url= url,json= payload)
# print(dat.raise_for_status())
dat.raise_for_status()
# print(dat)

# %%
dat=dat.json()
print(json.dumps(dat,indent=4))
# Out:
# {
#     "total": 36,
#     "jobPostings": [
#         {
#             "title": "Senior Software Engineer ( SONiC )",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Senior-Software-Engineer---SONiC--_202662",
#             "locationsText": "2 Locations",
#             "postedOn": "Posted Yesterday",
#             "bulletFields": [
#                 "202662"
#             ]
#         },
#         {
#             "title": "Test Automation Engineer (Optical Testing & Calibration)",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Test-Automation-Engineer--Optical-Testing---Calibration-_20251691",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted Yesterday",
#             "bulletFields": [
#                 "20251691"
#             ]
#         },
#         {
#             "title": "Manager - Transport Cal & Test Engineering",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Manager---Transport-Cal---Test-Engineering_202648",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 5 Days Ago",
#             "bulletFields": [
#                 "202648"
#             ]
#         },
#         {
#             "title": "System Software Engineer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/System-Software-Engineer_202682",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 6 Days Ago",
#             "bulletFields": [
#                 "202682"
#             ]
#         },
#         {
#             "title": "Embedded Security",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Embedded-Security_202675",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 6 Days Ago",
#             "bulletFields": [
#                 "202675"
#             ]
#         },
#         {
#             "title": "Engineer Staff, SW Development",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Engineer-Staff--SW-Development_202674",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 6 Days Ago",
#             "bulletFields": [
#                 "202674"
#             ]
#         },
#         {
#             "title": "Software Designer \u2013 Embedded Security",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Software-Designer---Embedded-Security_202664",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 6 Days Ago",
#             "bulletFields": [
#                 "202664"
#             ]
#         },
#         {
#             "title": "Software Supply Chain Security Engineer (SBOM & Vulnerability Management)",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Software-Supply-Chain-Security-Engineer--SBOM---Vulnerability-Management-_202665",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 6 Days Ago",
#             "bulletFields": [
#                 "202665"
#             ]
#         },
#         {
#             "title": "Senior Embedded Networking Developer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Senior-Embedded-Networking-Developer_202663",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 6 Days Ago",
#             "bulletFields": [
#                 "202663"
#             ]
#         },
#         {
#             "title": "Senior Platform Firmware Engineer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Senior-Platform-Firmware-Engineer_202685",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 6 Days Ago",
#             "bulletFields": [
#                 "202685"
#             ]
#         },
#         {
#             "title": "Embedded Software Engineer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Embedded-Software-Engineer_20251645",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 7 Days Ago",
#             "bulletFields": [
#                 "20251645"
#             ]
#         },
#         {
#             "title": "Optical Verification Engineer Co-op/Intern",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Optical-Verification-Engineer-Co-op-Intern_2026145",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 12 Days Ago",
#             "bulletFields": [
#                 "2026145"
#             ]
#         },
#         {
#             "title": "Embedded Software Developer Co-op (Optical Circuit Switch)",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Embedded-Software-Developer-Co-op--Optical-Circuit-Switch-_202668",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 12 Days Ago",
#             "bulletFields": [
#                 "202668"
#             ]
#         },
#         {
#             "title": "Principal Engineer, Silicon Photonics-MEMS R&D",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Sr-Manager-Silicon-Photonics-MEMS-R-D_20251976",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 13 Days Ago",
#             "bulletFields": [
#                 "20251976"
#             ]
#         },
#         {
#             "title": "Global Commodity Manager",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Global-Commodity-Manager_20251022",
#             "locationsText": "2 Locations",
#             "postedOn": "Posted 13 Days Ago",
#             "bulletFields": [
#                 "20251022"
#             ]
#         },
#         {
#             "title": "Sr. Optical Test Engineer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Sr-Optical-Test-Engineer_20263",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 27 Days Ago",
#             "bulletFields": [
#                 "20263"
#             ]
#         },
#         {
#             "title": "Product Engineer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Transport-Sustaining-Engineer_20251714",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 29 Days Ago",
#             "bulletFields": [
#                 "20251714"
#             ]
#         },
#         {
#             "title": "Process Automation Software Engineer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Test-Engineer--Optical-Calibration-and-Test-_20251740",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 30+ Days Ago",
#             "bulletFields": [
#                 "20251740"
#             ]
#         },
#         {
#             "title": "Product Engineer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Product-Engineer_20251872",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 30+ Days Ago",
#             "bulletFields": [
#                 "20251872"
#             ]
#         },
#         {
#             "title": "Senior FPGA Designer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Senior-FPGA-Designer_20251856",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 30+ Days Ago",
#             "bulletFields": [
#                 "20251856"
#             ]
#         }
#     ],
#     "facets": [
#         {
#             "facetParameter": "workerSubType",
#             "descriptor": "Job Type",
#             "values": [
#                 {
#                     "descriptor": "Regular",
#                     "id": "01232ead616f01a40eca613e6310c21d",
#                     "count": 29
#                 },
#                 {
#                     "descriptor": "Co-op Student",
#                     "id": "01232ead616f01ef5e875b3e6310c01d",
#                     "count": 7
#                 }
#             ]
#         },
#         {
#             "facetParameter": "jobFamily",
#             "descriptor": "Job Family",
#             "values": [
#                 {
#                     "descriptor": "Software Development Engineer",
#                     "id": "6e5aaa897f7210020a6d8d48a31b0000",
#                     "count": 8
#                 },
#                 {
#                     "descriptor": "Co-op",
#                     "id": "01232ead616f01b3893a2a926610ab2c",
#                     "count": 7
#                 },
#                 {
#                     "descriptor": "FIRMWARE ENGINEER",
#                     "id": "01232ead616f013675f49c926610eb2c",
#                     "count": 3
#                 },
#                 {
#                     "descriptor": "Hardware Development Engineer",
#                     "id": "23564498c7fe10020a1266cb0e1e0000",
#                     "count": 3
#                 },
#                 {
#                     "descriptor": "RELIABILITY/TEST ENGINEER",
#                     "id": "01232ead616f018251d216946610a72d",
#                     "count": 3
#                 },
#                 {
#                     "descriptor": "MANUFACTURING PRODUCT",
#                     "id": "01232ead616f01118ddc509366103b2d",
#                     "count": 2
#                 },
#                 {
#                     "descriptor": "SUPPLY CHAIN (GENERIC)",
#                     "id": "01232ead616f0158334c58946610cb2d",
#                     "count": 2
#                 },
#                 {
#                     "descriptor": "ELECTRICAL ENGINEER",
#                     "id": "01232ead616f013518ac61926610c92c",
#                     "count": 1
#                 },
#                 {
#                     "descriptor": "DEVELOPMENT ENGINEER",
#                     "id": "01232ead616f01b5aec550926610bf2c",
#                     "count": 1
#                 },
#                 {
#                     "descriptor": "DATA ANALYST",
#                     "id": "68df40de9ec901658d17735c92450417",
#                     "count": 1
#                 },
#                 {
#                     "descriptor": "Systems Design/Architecture Engineer",
#                     "id": "01232ead616f0147ca4072946610d92d",
#                     "count": 1
#                 },
#                 {
#                     "descriptor": "SW SYSTEMS ENGINEER",
#                     "id": "01232ead616f014f40af6a946610d52d",
#                     "count": 1
#                 },
#                 {
#                     "descriptor": "RELIABILITY ENGINEER",
#                     "id": "01232ead616f010a0e5613946610a52d",
#                     "count": 1
#                 },
#                 {
#                     "descriptor": "PATENT COUNSEL",
#                     "id": "01232ead616f0183239bb6936610712d",
#                     "count": 1
#                 },
#                 {
#                     "descriptor": "OPTICAL ENGINEER",
#                     "id": "01232ead616f0117f612a2936610652d",
#                     "count": 1
#                 }
#             ]
#         },
#         {
#             "facetParameter": "timeType",
#             "descriptor": "Time Type",
#             "values": [
#                 {
#                     "descriptor": "Full time",
#                     "id": "1f4855eb1d7b016ba7d45ba749097900",
#                     "count": 36
#                 }
#             ]
#         },
#         {
#             "facetParameter": "locationMainGroup",
#             "values": [
#                 {
#                     "facetParameter": "locations",
#                     "descriptor": "Locations",
#                     "values": [
#                         {
#                             "descriptor": "Thailand - Pathumthani (Navanakorn)",
#                             "id": "01232ead616f017c60e505496810ca71",
#                             "count": 45
#                         },
#                         {
#                             "descriptor": "Canada - Ottawa (Bill Leathem)",
#                             "id": "01232ead616f01726660254a6810e472",
#                             "count": 35
#                         },
#                         {
#                             "descriptor": "Japan - Sagamihara",
#                             "id": "01232ead616f0135a0b7fc496810bc72",
#                             "count": 26
#                         },
#                         {
#                             "descriptor": "USA - CA - San Jose (Ridder)",
#                             "id": "01232ead616f01188d163b496810fb71",
#                             "count": 24
#                         },
#                         {
#                             "descriptor": "China - Shenzhen (Nanshan)",
#                             "id": "01232ead616f018471c21b4a6810da72",
#                             "count": 14
#                         },
#                         {
#                             "descriptor": "United Kingdom - Towcester Northamptonshire",
#                             "id": "01232ead616f01ba3691454968100872",
#                             "count": 11
#                         },
#                         {
#                             "descriptor": "China - Wuhan",
#                             "id": "1fb4c923bb63010157aeb6a178fc0000",
#                             "count": 8
#                         },
#                         {
#                             "descriptor": "USA - CA - San Jose (Rose)",
#                             "id": "01232ead616f01b1faa624496810e371",
#                             "count": 6
#                         },
#                         {
#                             "descriptor": "China - Shenzhen (Futian)",
#                             "id": "172ddc3c681401161bb59a46c11bfdd5",
#                             "count": 5
#                         },
#                         {
#                             "descriptor": "USA - CA - San Jose (1751 Fox)",
#                             "id": "ea1c56baefa8019ebb23c8d1c600ac49",
#                             "count": 2
#                         },
#                         {
#                             "descriptor": "Canada - Ottawa (Terry Fox)",
#                             "id": "1fb4c923bb630100a0fa8c8bd49a0000",
#                             "count": 2
#                         },
#                         {
#                             "descriptor": "USA - CA - San Jose (Auto)",
#                             "id": "01232ead616f0186b81a35496810f371",
#                             "count": 1
#                         },
#                         {
#                             "descriptor": "Italy - Milan Sarca",
#                             "id": "5804a608c5b30104ea70349700024564",
#                             "count": 1
#                         },
#                         {
#                             "descriptor": "China - Dongguan (Changan Town)",
#                             "id": "2e07b6cf3c6a1000d08f9140324d0000",
#                             "count": 1
#                         },
#                         {
#                             "descriptor": "Thailand - Pathumthani",
#                             "id": "01232ead616f016e238b0e496810cf71",
#                             "count": 1
#                         },
#                         {
#                             "descriptor": "Brazil - Campinas (Cambacicas Avenue)",
#                             "id": "1286e551faef1001be76d9b70afb0000",
#                             "count": 1
#                         },
#                         {
#                             "descriptor": "Remote - USA - WA",
#                             "id": "01232ead616f01d58ed9604968102172",
#                             "count": 1
#                         }
#                     ]
#                 }
#             ]
#         }
#     ],
#     "userAuthenticated": false
# }

# %%
p= dat['jobPostings']
# print(type(p))
# print(p)
print(json.dumps(p,indent=4))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 p= dat['jobPostings']
#       2 # print(type(p))
#       3 # print(p)
#       4 print(json.dumps(p,indent=4))
#
# KeyError: 'jobPostings'

# %%
p["bulletFields"][0]
# Out:
# '202662'

# %%
job_list=p

# %%
url='https://lumentum.wd5.myworkdayjobs.com/wday/cxs/lumentum/LITE/job/Canada---Ottawa-Bill-Leathem/Senior-Software-Engineer---SONiC--_202662'

resp=rq.get(url= url)#, headers= headers)
print(resp)
print(resp.raise_for_status())
dat=resp.json()
# Out:
# <Response [200]>
# None

# %%
print(json.dumps(dat,indent=4))
# Out:
# {
#     "jobPostingInfo": {
#         "id": "dcf24fa98cb31001af81f0d853680000",
#         "title": "Senior Software Engineer ( SONiC )",
#         "jobDescription": "<p><span class=\"emphasis\">It&#39;s fun to work in a company where people truly BELIEVE in what they&#39;re doing!</span><br /><i>We&#39;re committed to bringing passion and customer focus to the business.</i></p><p><br /><i>If you like wild growth and working with happy, enthusiastic over-achievers, you&#39;ll enjoy your career with us!</i></p><p><br /><span>Lumentum Canada was awarded the 2022 National Capital Region\u2019s Top Employers <i><u>for the 6th consecutive year</u></i> and the 2022 Career Directory Canada\u2019s Best Employers for Recent Graduates <i><u>for the 5th consecutive year</u></i>. </span><br />\u00a0</p><p><b>Position Title: </b>Senior Software Engineer ( SONiC )</p><p><b>Employment Type: </b>Full-time, Existing vacancy</p><p><b>Location: </b>Ottawa ON, Onsite</p><p></p><p><b>About Lumentum</b></p><p>At Lumentum, we\u2019re building the tech behind the world\u2019s fastest networks and most advanced systems. Our optical and photonic solutions power everything from AI and cloud computing to data centers, telecom, and advanced manufacturing.</p><p></p><p>We\u2019re a global team of innovators working where light meets technology, solving big challenges that keep the world connected and moving forward. If shaping the future of connectivity excites you, you\u2019ll fit right in.</p><p></p><p><b>Why You\u2019ll Love This Role</b></p><p></p><p>We are seeking an experienced <b>SONiC expert</b> to <b>lead the design and development</b> of next-generation <b>optical circuit switch platforms</b>. This role will focus on SONiC platform architecture, SAI development, containerization, debian packaging, telemetry and fault management for optical systems. The successful candidate will collaborate across multiple engineering teams and contribute to upstream SONiC initiatives</p><p></p><div></div><p><b>What You\u2019ll Be Doing</b></p><ul><li><b>Define and own the SONiC platform architecture</b> for next-generation optical hardware platforms</li><li><b>Architect and drive SAI design and enablement</b> to support optical circuit switching use cases</li><li><b>Lead platform bring-up strategy</b>, including containerized services and Debian packaging</li><li><b>Own SONiC release strategy</b>, porting and stabilizing software across major releases</li><li><b>Architect telemetry, observability, and northbound integrations</b> (e.g., gNXI)</li><li><b>Design and implement fault/event driven framework </b>\u00a0for optical platforms</li><li><b>Drive cross-functional technical alignment</b> across hardware, firmware and manufacturing teams</li><li><b>Influence open networking direction</b> through upstream contributions to SONiC/OCP</li></ul><p></p><p></p><div></div><p><b>What We\u2019re Looking For</b></p><p></p><p><b>Education:</b><br />Bachelor\u2019s degree in computer science, Computer Engineering, Software Engineering, Electrical Engineering, or a related field</p><p></p><p><b>Experience:</b></p><ul><li>5&#43; years of experience in<b> C, C&#43;&#43; and Python</b></li><li>Migrating to major SONiC releases</li><li>Deep understanding of <b>SONiC architecture</b> ( core and host services, NBI, database)</li><li>Strong <b>Linux, Docker, Debian packaging,</b> <b>build systems, shell scripting </b>and Git skills</li><li>Hands-on\u00a0 system bring-up experience, SAI development and platform integration</li><li>Proven experience with telemetry, system events</li></ul><p></p><p><b>Asset/Nice to Have</b></p><ul><li>Prior contributions to SONiC or OCP open-source networking projects</li><li>Knowledge of large-scale datacenter networking and optical transport technologies</li><li>Experience with software defined optical networks (SDON)</li></ul><p></p><p><b>Why This Role Matters</b></p><p></p><p>This position provides an opportunity to contribute directly to the evolution of SONiC for optical switching technologies and next-generation datacenter environments. The role offers exposure to complex engineerin ...
#         "location": "Canada - Ottawa (Bill Leathem)",
#         "additionalLocations": [
#             "USA - CA - San Jose (Auto)"
#         ],
#         "postedOn": "Posted Yesterday",
#         "startDate": "2026-02-24",
#         "timeType": "Full time",
#         "jobReqId": "202662",
#         "jobPostingId": "Senior-Software-Engineer---SONiC--_202662",
#         "jobPostingSiteId": "LITE",
#         "country": {
#             "descriptor": "Canada",
#             "id": "a30a87ed25634629aa6c3958aa2b91ea"
#         },
#         "canApply": true,
#         "posted": true,
#         "includeResumeParsing": true,
#         "jobRequisitionLocation": {
#             "descriptor": "Canada - Ottawa (Bill Leathem)",
#             "country": {
#                 "descriptor": "Canada",
#                 "id": "a30a87ed25634629aa6c3958aa2b91ea",
#                 "alpha2Code": "CA"
#             }
#         },
#         "externalUrl": "https://lumentum.wd5.myworkdayjobs.com/LITE/job/Canada---Ottawa-Bill-Leathem/Senior-Software-Engineer---SONiC--_202662",
#         "questionnaireId": "fb593d46419901c0275448e8cf0c12fe"
#     },
#     "hiringOrganization": {
#         "name": "Lumentum Operations LLC",
#         "url": ""
#     },
#     "similarJobs": [
#         {
#             "title": "Senior Embedded Software Designer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Senior-Embedded-Software-Designer_2024990",
#             "timeType": "Full time",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 30+ Days Ago",
#             "startDate": "2025-07-17"
#         },
#         {
#             "title": "Embedded Software Engineer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Embedded-Software-Engineer_20251645",
#             "timeType": "Full time",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 7 Days Ago",
#             "startDate": "2026-02-18"
#         },
#         {
#             "title": "System Software Engineer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/System-Software-Engineer_202682",
#             "timeType": "Full time",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 6 Days Ago",
#             "startDate": "2026-02-19"
#         },
#         {
#             "title": "Embedded Linux Software Designer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Senior-Embedded-Application-Developer_2024824",
#             "timeType": "Full time",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 30+ Days Ago",
#             "startDate": "2025-05-27"
#         },
#         {
#             "title": "Senior Platform Firmware Engineer",
#             "externalPath": "/job/Canada---Ottawa-Bill-Leathem/Senior-Platform-Firmware-Engineer_202685",
#             "timeType": "Full time",
#             "locationsText": "Canada - Ottawa (Bill Leathem)",
#             "postedOn": "Posted 6 Days Ago",
#             "startDate": "2026-02-19"
#         }
#     ],
#     "userAuthenticated": false
# }

# %%
s='https://lumentum.wd5.myworkdayjobs.com/LITE/job/Canada---Ottawa-Bill-Leathem/Embedded-Software-Engineer_20251645'

import re
index=s.find('job/')
s[index+4:]
# Out:
# 'Canada---Ottawa-Bill-Leathem/Embedded-Software-Engineer_20251645'
